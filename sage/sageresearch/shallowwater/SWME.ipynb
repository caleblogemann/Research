# %%
import sageresearch.shallowwater.shallow_water_moment_equations as swme

# %% [markdown]
# # Velocity Basis Functions

# %%
num_moments = 3
phi = swme.get_velocity_basis_functions(num_moments)
plot(phi, x, 0, 1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
# Out:
# 1

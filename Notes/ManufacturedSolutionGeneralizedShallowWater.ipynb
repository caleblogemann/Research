# %%
x = var('x')
t = var('t')
x_0 = -1/2;
nu = 0;
lam = 1;

num_eqns = 2;

exact_height(t, x) = 1 + exp(3 * cos(pi*(x - t - x_0)) + 4)
exact_velocity(t, x) = 1
exact_s(t, x) = 0
exact_k(t, x) = 0
exact_m(t, x) = 0
exact_solution_primitive(t, x) = [exact_height(t, x), 
                                  exact_velocity(t, x), 
                                  exact_s(t, x), 
                                         exact_k(t, x),
                                         exact_m(t, x)]
exact_solution_conserved(t, x) = [exact_height(t, x), 
                                         exact_height(t, x) * exact_velocity(t, x), 
                                         exact_height(t, x) * exact_s(t, x),
                                         exact_height(t, x) * exact_k(t, x),
                                         exact_height(t, x) * exact_m(t, x)]
# Out:
#   File "<ipython-input-18-6d3ab42c5bd4>", line 14
#     __tmp__=var("t,x"); exact_solution_primitive = symbolic_expression([exact_height(t, x), ).function(t,x)
#                                                                                             ^
# SyntaxError: invalid syntax

# %%
plot(lambda x: exact_height(0.0, x), -1, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
exact_height.derivative(t)
# Out:
# (t, x) |--> 3*pi*e^(3*cos(1/2*pi - pi*t + pi*x) + 4)*sin(1/2*pi - pi*t + pi*x)

# %%
test(t, x) = vector([exact_height(t, x)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4e6ef7c9ea43> in <module>()
# ----> 1 __tmp__=var("t,x"); test = symbolic_expression(vector([exact_height(t, x)])).function(t,x)
#
# /Users/logemann/Applications/SageMath/local/lib/python2.7/site-packages/sage/calculus/all.pyc in symbolic_expression(x)
#     105         return vector(SR,x)
#     106     else:
# --> 107         return SR(x)
#     108
#     109 from . import desolvers
#
# /Users/logemann/Applications/SageMath/local/lib/python2.7/site-packages/sage/structure/parent.pyx in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:9197)()
#     898         if mor is not None:
#     899             if no_extra_args:
# --> 900                 return mor._call_(x)
#     901             else:
#     902                 return mor._call_with_args(x, args, kwds)
#
# ...
